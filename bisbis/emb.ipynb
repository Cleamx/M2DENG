# %%
import pandas as pd
import numpy as np
import pickle
import nltk.tokenize import RegexTokenizer
from sklearn.manifold import TSNE
# Out:
#   Cell In[3], line 4
#     import nltk.tokenize import RegexTokenizer
#                          ^
# SyntaxError: invalid syntax
